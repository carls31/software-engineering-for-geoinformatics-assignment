# %%
# Import pandas module
import pandas as pd
from df_request import *

# country & pollutants list website
'''https://discomap.eea.europa.eu/map/fme/latest/files.txt'''

# Countries to download
# Note: List is not complete
countries = ['SE']
# Pollutant to be downloaded
pollutants = ['PM10']

file = download_request(countries, pollutants)
df = pd.read_csv("SE_PM10.csv")
df.head()
# Out:
# -----------------------------------------------------------------------
# Downloading: http://discomap.eea.europa.eu/map/fme/latest/SE_PM10.csv
# Saved locally as: SE_PM10.csv
# -----
# Download finished
#   network_countrycode network_localid                     network_name  \
# 0                  SE     NET-SE0004C  Östra Sveriges Luftvårdsförbund
# 1                  SE     NET-SE0004C  Östra Sveriges Luftvårdsförbund
# 2                  SE     NET-SE0004C  Östra Sveriges Luftvårdsförbund
# 3                  SE     NET-SE0004C  Östra Sveriges Luftvårdsförbund
# 4                  SE     NET-SE0004C  Östra Sveriges Luftvårdsförbund
#
#   network_namespace                                   network_timezone  \
# 0          SE.NV.AQ  http://dd.eionet.europa.eu/vocabulary/aq/timez...
# 1          SE.NV.AQ  http://dd.eionet.europa.eu/vocabulary/aq/timez...
# 2          SE.NV.AQ  http://dd.eionet.europa.eu/vocabulary/aq/timez...
# 3          SE.NV.AQ  http://dd.eionet.europa.eu/vocabulary/aq/timez...
# 4          SE.NV.AQ  http://dd.eionet.europa.eu/vocabulary/aq/timez...
#
#   pollutant   samplingpoint_localid samplingpoint_namespace  samplingpoint_x  \
# 0      PM10  SPO-SE159402_00005_100                SE.NV.AQ        17.954993
# 1      PM10  SPO-SE159402_00005_100                SE.NV.AQ        17.954993
# 2      PM10  SPO-SE159402_00005_100                SE.NV.AQ        17.954993
# 3      PM10  SPO-SE159402_00005_100                SE.NV.AQ        17.954993
# 4      PM10  SPO-SE159402_00005_100                SE.NV.AQ        17.954993
#
#    samplingpoint_y  ... station_namespace       value_datetime_begin  \
# 0        59.445922  ...          SE.NV.AQ  2023-04-12 06:00:00+01:00
# 1        59.445922  ...          SE.NV.AQ  2023-04-12 07:00:00+01:00
# 2        59.445922  ...          SE.NV.AQ  2023-04-12 08:00:00+01:00
# 3        59.445922  ...          SE.NV.AQ  2023-04-12 09:00:00+01:00
# 4        59.445922  ...          SE.NV.AQ  2023-04-12 10:00:00+01:00
#
#           value_datetime_end    value_datetime_inserted  \
# 0  2023-04-12 07:00:00+01:00  2023-04-12 13:29:39+01:00
# 1  2023-04-12 08:00:00+01:00  2023-04-12 13:29:39+01:00
# 2  2023-04-12 09:00:00+01:00  2023-04-12 13:44:05+01:00
# 3  2023-04-12 10:00:00+01:00  2023-04-12 14:27:06+01:00
# 4  2023-04-12 11:00:00+01:00  2023-04-12 14:42:34+01:00
#
#   value_datetime_updated value_numeric value_validity value_verification  \
# 0                 +01:00       22.4475              1                  3
# 1                 +01:00       31.2050              1                  3
# 2                 +01:00       59.2775              1                  3
# 3                 +01:00       73.7775              1                  3
# 4                 +01:00       81.3550              1                  3
#
#   station_altitude  value_unit
# 0             14.0       ug/m3
# 1             14.0       ug/m3
# 2             14.0       ug/m3
# 3             14.0       ug/m3
# 4             14.0       ug/m3
#
# [5 rows x 24 columns]
